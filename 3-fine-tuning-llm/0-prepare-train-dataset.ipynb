# %%
import os

print("原始工作路径:", os.getcwd())
os.chdir("/workspace/")
print("新工作路径:", os.getcwd())
# Out:
# 原始工作路径: /
# 新工作路径: /workspace

# %%
# !wget https://github.com/zhangsheng93/cMedQA2/raw/refs/heads/master/question.zip
# Out:
# --2025-08-09 01:41:01--  https://github.com/zhangsheng93/cMedQA2/raw/refs/heads/master/question.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/zhangsheng93/cMedQA2/refs/heads/master/question.zip [following]
# --2025-08-09 01:41:02--  https://raw.githubusercontent.com/zhangsheng93/cMedQA2/refs/heads/master/question.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7701487 (7.3M) [application/zip]
# Saving to: ‘question.zip’
#
# question.zip        100%[===================>]   7.34M  --.-KB/s    in 0.02s
#
# 2025-08-09 01:41:03 (315 MB/s) - ‘question.zip’ saved [7701487/7701487]

# %%
# !wget https://github.com/zhangsheng93/cMedQA2/raw/refs/heads/master/answer.zip
# Out:
# --2025-08-09 01:41:07--  https://github.com/zhangsheng93/cMedQA2/raw/refs/heads/master/answer.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/zhangsheng93/cMedQA2/refs/heads/master/answer.zip [following]
# --2025-08-09 01:41:08--  https://raw.githubusercontent.com/zhangsheng93/cMedQA2/refs/heads/master/answer.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27610046 (26M) [application/zip]
# Saving to: ‘answer.zip’
#
# answer.zip          100%[===================>]  26.33M  18.0MB/s    in 1.5s
#
# 2025-08-09 01:41:11 (18.0 MB/s) - ‘answer.zip’ saved [27610046/27610046]

# %%
# !unzip question.zip
# Out:
# Archive:  question.zip
#   inflating: question.csv

# %%
# !unzip answer.zip
# Out:
# Archive:  answer.zip
#   inflating: answer.csv

# %%
import csv
from itertools import islice

def csv_to_dict(csv_file):
    data = []
    with open(csv_file, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            data.append(row)
    return data

question = csv_to_dict('question.csv')
for item in islice(question, 10):
    print(f"{item}")
# Out:
# {'question_id': '65102009', 'content': '头痛恶心肌肉痛关节痛颈部淋巴结疼痛怎么回事啊'}
# {'question_id': '44275784', 'content': '我怀孕37周，肠子一直呼噜呼噜叫感觉像是在里面灌水，上厕所拉稀和喷水一样，一天上厕所5次，对孩子有啥影响，应该怎么办？'}
# {'question_id': '42163349', 'content': '男，67岁，2天前突然出现右小腿（类似抽筋症状），现出现右小腿消肿，有指压痕，无，请问可能是什么疾病，该如何诊治'}
# {'question_id': '67935540', 'content': '怀孕前两个月照了CT和X光，来两次月经后怀孕了，怀孕期间有轻微盆腔积水吃了两瓶杏香兔耳片。请问这对孩子影响有多大'}
# {'question_id': '33429289', 'content': '阴囊湿冷阳痿早泻请问用点什么药'}
# {'question_id': '28517513', 'content': '发烧全身发烫怎么办？能不能开空调的啊？？开始是全身无力，吃了药好了点。晚上睡觉空调开起来的，早上身体很烫。'}
# {'question_id': '24279043', 'content': '怀孕30周了，照了彩超，宝宝脐带绕颈已周，头位？怀孕30周了，照了彩超，宝宝脐带绕颈已周，头位在下腹，这几天胎动明显减少，去医院听了胎音是正常的，但是心里还是很担心，请问有问题吗。'}
# {'question_id': '46574274', 'content': '脚孤拐外侧肿胀疼痛怎么办用个什么药？'}
# {'question_id': '56439498', 'content': '问题描述:我射精的时候精子射出来的那一瞬间阴茎下面很痛有时候小便也有一点点痛但没射精时那么厉害就想刺刺的一样请问是怎么搞的'}
# {'question_id': '37489044', 'content': '为什么抽完血后会出现头晕、四肢无力脸色发白冒汗等现象？、请问为什么我抽完血后会出现头晕、四肢无力脸色发白和冒汗这些现象？是不是我身体里供血不足？谢谢'}

# %%
answer = csv_to_dict('answer.csv')
for item in islice(answer, 10):
    print(f"{item}")
# Out:
# {'ans_id': '0', 'question_id': '45619783', 'content': '月经延迟十四天而且伴随恶心，头痛，乏力的现象，那么考虑怀孕的概率是非常大的，建议你去医院检查血HCG或者B超确诊是否怀孕，如果怀孕了，那么怀孕的天数大概是44天如果打算保留这个孩子，从现在开始要戒烟酒，不要同房，注意休息，饮食方面要少吃辛辣刺激的，腌制，油炸，烧烤的食物，不要吃凉性的食物，不要吃螃蟹甲鱼等寒性食品，容易流产，定期孕检'}
# {'ans_id': '1', 'question_id': '45619783', 'content': '如果你的月经周期规律，有正常的性生活，未采取任何有效的避孕措施，此时的症状考虑有怀孕的可能。你的情况，如果担心怀孕，可严密观察，如果月经延迟一周以上，则到正规医院妇科进行血HCG、B超等相关检查，确诊是否怀孕'}
# {'ans_id': '2', 'question_id': '45619783', 'content': '建议在性生活过后14天左右可以用怀孕试纸自我检测一下，一般怀孕试纸显示2条线的话是怀孕了的，一条线的话没有怀孕，有2条线，一条线明显，另一条线不明显，那么是弱阳性，试纸显示弱阳性有两种可能，一种是怀孕了，一种是炎症。同样可以去医院做血HCG的检查，这个准确率是很高的。'}
# {'ans_id': '3', 'question_id': '26616465', 'content': '头痛是临床上最为常见的临床症状之一，是人体对各种致痛因素所产生的主观感觉，属于疼痛的范畴。建议临床上最常用的是非甾体抗炎镇痛药，包括对乙酰氨基酚，布洛芬、双氯酚酸钾等。必要时做脑部CT检查一下。'}
# {'ans_id': '4', 'question_id': '26616465', 'content': '头痛主要是由于头部的血管、神经、脑膜等对疼痛敏感的组织受到刺激引起的。由紧张、疲劳、饮酒等原因造成的头痛经过休息之后可自然消退。头痛即可作为神经系统原发病的一个早期症状或中、晚期症状，如脑肿瘤患者以头痛为主诉者更是普遍。头痛也可以是颈部疾病，肩部疾病及背部疾病的症状，也可以是全身疾病在头部的一个表现形式，如严重的细菌性感染时出现的头痛，正是由于引起头痛的原因多而复杂，因此其临床分类也十分复杂，需要到医院检查确诊。'}
# {'ans_id': '5', 'question_id': '26616465', 'content': ':考虑是神经性头疼，是一种功能性的疾病，是由于紧张压力或是精神因素引起的神经功能失调造成的头痛，也有一定的遗传因素，一般可考虑吃些中草药川芎茶调散来治疗。同时结合针灸按摩，效果会更好的。'}
# {'ans_id': '6', 'question_id': '4607191', 'content': '一般是由于结膜炎症活干炎症引起的，可以到医院检查一下。'}
# {'ans_id': '7', 'question_id': '14532710', 'content': '心脏在那个位置，心脏绞痛在那，也可能是胃痛导致的，胃痛位置比心脏偏下一点。'}
# {'ans_id': '8', 'question_id': '14532710', 'content': '左边有很多脏器，比如心，胃，肠等，你可以具体描述一下疼痛的性质，是钝痛，锐痛还是绞痛，以便于确诊以后对症治疗'}
# {'ans_id': '9', 'question_id': '14532710', 'content': '正常情况下，左胸下是心脏的位置，你可能是心脏发生病变，建议你去医院做进一步检查，以明确诊断，对症治疗，希望对你有帮助。'}

# %%
question_dict = {}

# 遍历列表并构建字典
for item in question:
    question_dict[item['question_id']] = item['content']

#print(question_dict)

# %%
answer_dict = {}

# 遍历列表并构建字典
for item in answer:
    answer_dict[item['question_id']] = item['content']

#print(answer_dict)

# %%
common_keys = question_dict.keys() & answer_dict.keys()

merged_dict = {question_dict[k]: answer_dict[k] for k in common_keys}

# %%
count = 0
for key, value in merged_dict.items():
    print(f"{key}: {value}")
    count += 1
    if count >= 10:
        break
# Out:
# 是否必须做胃镜确诊？去年做过彩超检查是胃下垂，胃炎。总是胃难受。: 根据你的叙述，有胃难受的症状，你比较年轻，一般的胃炎口服药物基本可以治愈。要想确诊，还是胃镜检查最好。平时规律饮食，禁忌生冷及辛辣刺激性的食物。
# 我怀孕29周，胎盘成熟度2级，对胎儿有什么影响。饮食改主意什么。: 应该是没有影响的，建议你可以到医院产科给予相关的产前检查，可以给予调整饮食的，给予多吃蔬菜谁高
# 头痛发热，脖子酸痛很难受: 看了你的症状，我建议可以吃点速效和泰诺等治疗，不用担心，问题不严重的期间一定要多喝水，多吃蔬菜和水果，也可以泡点姜水来喝，不过一般情况下吃完药就没事了
# 每次来大姨妈的前三四天量都很少，中间两三天量多了，到后面三四天量较少，请问这是为什么啊？我本身有中度宫颈糜烂，经期这么长是什么原因呢？还是因为别的妇科病啊？一般这样是什么原因？: 根据你的叙说应该是经期延长，有无其他症状，如痛经，腰痛，小腹下坠等，可以先去医院做个B超及6项激素检查。我建议你，注意个人经期卫生，加强营养，可以先做B超及激6项检查后，在治疗。
# 双顶径84mm，股骨长68mm，头围299mm，腹围348mm，请问宝宝现在有多重: 胎儿的体重可以根据双顶径大小来进行估算，胎儿的体重=双顶径大小X900-5200，这样计算的话，你的胎儿体重大概是2360g。这并不代表胎儿的实际出生体重，只是一种大概的体重，实际出生体重与计算的体重有正负15%的误差，希望对你有帮助。
# 包皮手术怎么样包皮手术怎么样包皮手术怎么样: 包皮手术常用于包皮过长，由于包皮长，包皮垢易存留于包皮内，易诱发龟头炎，龟头敏感等，也是妇科炎症的诱因之一如果。包皮过长建议手术治疗，常用包皮环切术，疗效肯定，恢复较快，操作简单。其次采用一次性切除吻合期，手术时间短，但价格较高，具体请咨询当地医师
# 扁桃体经常反复发炎，咽喉也经常会痛。咽喉痛的时候也不会感冒，也没有发烧。扁桃体炎上回去医院检查了，医生说是慢性扁桃体炎。之前一直吃西药，阿奇霉素片，头孢之类的，也打了好长时间的针。最近在吃熬的中药，医生开了十几味，里面有金银花、麦冬等，吃了1个星期扁桃体好了，就是喉咙还有点痛。: 扁桃体发炎如果是病毒感染可以使用利巴韦林颗粒治疗。最好做一下血常规检查，明确感染病因再选择药物治疗，细菌感染可以使用头孢类消炎药治疗。
# 起水疱砖心的痒好几年了用过达克宁泡过醋泡过盐有什么办法快速止痒: 脚气是真菌感染所致的皮肤病此种情况你可以使用珊瑚癣净，进行浸泡后，再外用复方酮康唑霜治疗，注意治疗后及时的将鞋袜进行清洗杀菌处理，以免复发。
# 关节疼痛，右腿发软，无法受力？昨天晚上突然开始右腿膝盖部分疼痛难忍，站立时腿会发软，晚上睡觉很难翻身，只要蹲下来就站不起来了，右腿弯曲和伸直的时候就会非常疼痛。没有治疗情况我想知道是什么病？有什么药可以治疗吗？: 要注意退化性膝关节炎的影响，具体可给予骨科和ct的检查诊断鉴别。可给予中药的洗浴浸泡或是中药的包扎固定，注意加强活血化瘀和补气补血的药物调理，注意在走路活动用力时尽量给予护膝或弹性绑带的固定措施。
# 我哥4年前一次车祸导致腰部以下瘫痪，双手也没有知觉。请问有没有治愈的能？第一次是在我们当地医院抢救治疗。: 从你讲的情况来看，你哥哥有车祸病史，有脊髓横断性损伤，腰部以下截瘫，双上肢感觉障碍。建议积极加强功能训练，进行康复治疗，防止关节强直，保持肢体关节正常活动，可做中医针灸及理疗。

# %%
import json

# 构建目标结构
result_list = []
for question, answer in merged_dict.items():
    conversations = []
    conversations.append({"role": "user", "content": question})
    conversations.append({"role": "assistant", "content": answer})
    result_list.append({"conversations": conversations})

# 转换为 JSON 并格式化输出
json_str = json.dumps(result_list, indent=2, ensure_ascii=False)
with open('med-train-dateset.json', 'w', encoding='utf-8') as f:
    f.write(json_str)
